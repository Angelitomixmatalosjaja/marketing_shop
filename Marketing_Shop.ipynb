# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
ifood = pd.read_csv('ifood_df.csv')

# %%
ifood
# Out:
#        Income  Kidhome  Teenhome  Recency  MntWines  MntFruits  \
# 0     58138.0        0         0       58       635         88
# 1     46344.0        1         1       38        11          1
# 2     71613.0        0         0       26       426         49
# 3     26646.0        1         0       26        11          4
# 4     58293.0        1         0       94       173         43
# ...       ...      ...       ...      ...       ...        ...
# 2200  61223.0        0         1       46       709         43
# 2201  64014.0        2         1       56       406          0
# 2202  56981.0        0         0       91       908         48
# 2203  69245.0        0         1        8       428         30
# 2204  52869.0        1         1       40        84          3
#
#       MntMeatProducts  MntFishProducts  MntSweetProducts  MntGoldProds  ...  \
# 0                 546              172                88            88  ...
# ...

# %%
igresos_promedio = ifood['Income'].mean()
print(f'Ingresos promedio: \n {igresos_promedio}')
# Out:
# Ingresos promedio:
#  51622.0947845805

# %%
ingresos_std = ifood['Income'].std()
print(f'Desviación estándar de los ingresos: \n {ingresos_std}')
# Out:
# Desviación estándar de los ingresos:
#  20713.06382588019

# %% [markdown]
# ## Personas que aceptaron en la primera campaña de marketing

# %%
personas_de_la_primera_campaña = ifood['AcceptedCmp1'].sum()
print(f'Personas que aceptaron la primera campaña: \n {personas_de_la_primera_campaña}')
personas_de_la_primera_campaña_rechazaron = len(ifood) - personas_de_la_primera_campaña
print(f'Personas que rechazaron la primera campaña: \n {personas_de_la_primera_campaña_rechazaron}')
porcentaje_primera_campaña = (personas_de_la_primera_campaña / len(ifood)) * 100
print(f'Porcentaje de personas que aceptaron la primera campaña: \n {porcentaje_primera_campaña:.2f}%')
# Out:
# Personas que aceptaron la primera campaña:
#  142
# Personas que rechazaron la primera campaña:
#  2063
# Porcentaje de personas que aceptaron la primera campaña:
#  6.44%

# %% [markdown]
# ## Personas que aceptaron en la segunda campaña de marketing

# %%
personas_de_la_segunda_campaña = ifood['AcceptedCmp2'].sum()
print(f'Personas que aceptaron la segunda campaña: \n {personas_de_la_segunda_campaña}')
personas_de_la_segunda_campaña_rechazaron = len(ifood) - personas_de_la_segunda_campaña
print(f'Personas que rechazaron la segunda campaña: \n {personas_de_la_segunda_campaña_rechazaron}')
porcentaje_segunda_campaña = (personas_de_la_segunda_campaña / len(ifood)) * 100
print(f'Porcentaje de personas que aceptaron la segunda campaña: \n {porcentaje_segunda_campaña:.2f}%')
# Out:
# Personas que aceptaron la segunda campaña:
#  30
# Personas que rechazaron la segunda campaña:
#  2175
# Porcentaje de personas que aceptaron la segunda campaña:
#  1.36%

# %% [markdown]
# ## Personas que aceptaron en la tercera campapaña de marketing

# %%
personas_de_la_tercera_campaña = ifood['AcceptedCmp3'].sum()
print(f'Personas que aceptaron la tercera campaña: \n {personas_de_la_tercera_campaña}')
personas_de_la_tercera_campaña_rechazaron = len(ifood) - personas_de_la_tercera_campaña
print(f'Personas que rechazaron la tercera campaña: \n {personas_de_la_tercera_campaña_rechazaron}')
porcentaje_tercera_campaña = (personas_de_la_tercera_campaña / len(ifood)) * 100
print(f'Porcentaje de personas que aceptaron la tercera campaña: \n {porcentaje_tercera_campaña:.2f}%')
# Out:
# Personas que aceptaron la tercera campaña:
#  163
# Personas que rechazaron la tercera campaña:
#  2042
# Porcentaje de personas que aceptaron la tercera campaña:
#  7.39%

# %% [markdown]
# ## Personas que aceptaron en la cuarta campaña de marketing

# %%
personas_de_la_cuarta_campaña = ifood['AcceptedCmp4'].sum()
print(f'Personas que aceptaron la cuarta campaña: \n {personas_de_la_cuarta_campaña}')
personas_de_la_cuarta_campaña_rechazaron = len(ifood) - personas_de_la_cuarta_campaña
print(f'Personas que rechazaron la cuarta campaña: \n {personas_de_la_cuarta_campaña_rechazaron}')
porcentaje_cuarta_campaña = (personas_de_la_cuarta_campaña / len(ifood)) * 100
print(f'Porcentaje de personas que aceptaron la cuarta campaña: \n {porcentaje_cuarta_campaña:.2f}%')
# Out:
# Personas que aceptaron la cuarta campaña:
#  164
# Personas que rechazaron la cuarta campaña:
#  2041
# Porcentaje de personas que aceptaron la cuarta campaña:
#  7.44%

# %% [markdown]
# ## Personas que acpetaron en la quinta campaña de marketing

# %%
personas_de_la_quinta_campaña = ifood['AcceptedCmp5'].sum()
print(f'Personas que aceptaron la quinta campaña: \n {personas_de_la_quinta_campaña}')
personas_de_la_quinta_campaña_rechazaron = len(ifood) - personas_de_la_quinta_campaña
print(f'Personas que rechazaron la quinta campaña: \n {personas_de_la_quinta_campaña_rechazaron}')
porcentaje_quinta_campaña = (personas_de_la_quinta_campaña / len(ifood)) * 100
print(f'Porcentaje de personas que aceptaron la quinta campaña: \n {porcentaje_quinta_campaña:.2f}%')
# Out:
# Personas que aceptaron la quinta campaña:
#  161
# Personas que rechazaron la quinta campaña:
#  2044
# Porcentaje de personas que aceptaron la quinta campaña:
#  7.30%

# %% [markdown]
# ## Personas de la ultima campaña de marketing

# %%
personas_ultima_campaña = ifood['Response'].sum()
print(f'Personas que aceptaron la última campaña: \n {personas_ultima_campaña}')
personas_ultima_campaña_rechazaron = len(ifood) - personas_ultima_campaña
print(f'Personas que rechazaron la última campaña: \n {personas_ultima_campaña_rechazaron}')
porcentaje_ultima_campaña = (personas_ultima_campaña / len(ifood)) * 100
print(f'Porcentaje de personas que aceptaron la última campaña: \n {porcentaje_ultima_campaña:.2f}%')
# Out:
# Personas que aceptaron la última campaña:
#  333
# Personas que rechazaron la última campaña:
#  1872
# Porcentaje de personas que aceptaron la última campaña:
#  15.10%

# %%
## suma de los porcentajes de aceptación de todas las campañas
suma_porcentajes = (porcentaje_primera_campaña + porcentaje_segunda_campaña + porcentaje_tercera_campaña +
                    porcentaje_cuarta_campaña + porcentaje_quinta_campaña + porcentaje_ultima_campaña)
print(f'Suma de los porcentajes de aceptación de todas las campañas: \n {suma_porcentajes:.2f}%')
# promedio de los porcentajes de aceptación de todas las campañas
promedio_porcentajes = suma_porcentajes / 6
print(f'Promedio de los porcentajes de aceptación de todas las campañas: \n {promedio_porcentajes:.2f}%')
# desviación estándar de los porcentajes de aceptación de todas las campañas
std_porcentajes = np.std([porcentaje_primera_campaña, porcentaje_segunda_campaña, porcentaje_tercera_campaña,
                          porcentaje_cuarta_campaña, porcentaje_quinta_campaña, porcentaje_ultima_campaña])
print(f'Desviación estándar de los porcentajes de aceptación de todas las campañas: \n {std_porcentajes:.2f}%')
# Out:
# Suma de los porcentajes de aceptación de todas las campañas:
#  45.03%
# Promedio de los porcentajes de aceptación de todas las campañas:
#  7.51%
# Desviación estándar de los porcentajes de aceptación de todas las campañas:
#  4.01%

# %%
## pie chart de todas las cmapañas
labels = ['Aceptaron', 'Rechazaron']
sizes_primera = [personas_de_la_primera_campaña, personas_de_la_primera_campaña_rechazaron]
sizes_segunda = [personas_de_la_segunda_campaña, personas_de_la_segunda_campaña_rechazaron]
sizes_tercera = [personas_de_la_tercera_campaña, personas_de_la_tercera_campaña_rechazaron]
sizes_cuarta = [personas_de_la_cuarta_campaña, personas_de_la_cuarta_campaña_rechazaron]
sizes_quinta = [personas_de_la_quinta_campaña, personas_de_la_quinta_campaña_rechazaron]
sizes_ultima = [personas_ultima_campaña, personas_ultima_campaña_rechazaron]
colors = ['#ff9999','#66b3ff']
explode = (0.1, 0)
fig, axs = plt.subplots(2, 3, figsize=(15, 10))
axs[0, 0].pie(sizes_primera, explode=explode, labels=labels, colors=colors, autopct='%1.1f%%', startangle=140)
axs[0, 0].set_title('Primera Campaña')
axs[0, 1].pie(sizes_segunda, explode=explode, labels=labels, colors=colors, autopct='%1.1f%%', startangle=140)
axs[0, 1].set_title('Segunda Campaña')
axs[0, 2].pie(sizes_tercera, explode=explode, labels=labels, colors=colors, autopct='%1.1f%%', startangle=140)
axs[0, 2].set_title('Tercera Campaña')
axs[1, 0].pie(sizes_cuarta, explode=explode, labels=labels, colors=colors, autopct='%1.1f%%', startangle=140)
axs[1, 0].set_title('Cuarta Campaña')
axs[1, 1].pie(sizes_quinta, explode=explode, labels=labels, colors=colors, autopct='%1.1f%%', startangle=140)
axs[1, 1].set_title('Quinta Campaña')
axs[1, 2].pie(sizes_ultima, explode=explode, labels=labels, colors=colors, autopct='%1.1f%%', startangle=140)
axs[1, 2].set_title('Última Campaña')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Afecta el estado civil la decesion a la hora de las campañas?

# %%
estadocivil_primera = ((ifood['marital_Single'] == 1) & (ifood['AcceptedCmp1'] == 1)).sum()
estadocivil_segunda = ((ifood['marital_Single'] == 1) & (ifood['AcceptedCmp2'] == 1)).sum()
estadocivil_tercera = ((ifood['marital_Single'] == 1) & (ifood['AcceptedCmp3'] == 1)).sum()
estadocivil_cuarta = ((ifood['marital_Single'] == 1) & (ifood['AcceptedCmp4'] == 1)).sum()
estadocivil_quinta = ((ifood['marital_Single'] == 1) & (ifood['AcceptedCmp5'] == 1)).sum()
estadocivil_ultima = ((ifood['marital_Single'] == 1) & (ifood['Response'] == 1)).sum()
print(f'Personas solteras que aceptaron la primera campaña: \n {estadocivil_primera}')
print(f'Personas solteras que aceptaron la segunda campaña: \n {estadocivil_segunda}')
print(f'Personas solteras que aceptaron la tercera campaña: \n {estadocivil_tercera}')
print(f'Personas solteras que aceptaron la cuarta campaña: \n {estadocivil_cuarta}')
print(f'Personas solteras que aceptaron la quinta campaña: \n {estadocivil_quinta}')
print(f'Personas solteras que aceptaron la última campaña: \n {estadocivil_ultima}')
todos_single = (estadocivil_primera + estadocivil_segunda + estadocivil_tercera +
                estadocivil_cuarta + estadocivil_quinta + estadocivil_ultima)
print(f'Total de personas solteras que aceptaron alguna campaña: \n {todos_single}')
# Out:
# Personas solteras que aceptaron la primera campaña:
#  31
# Personas solteras que aceptaron la segunda campaña:
#  5
# Personas solteras que aceptaron la tercera campaña:
#  39
# Personas solteras que aceptaron la cuarta campaña:
#  32
# Personas solteras que aceptaron la quinta campaña:
#  32
# Personas solteras que aceptaron la última campaña:
#  109
# Total de personas solteras que aceptaron alguna campaña:
#  248

# %%
casados_primera = ((ifood['marital_Married'] == 1) & (ifood['AcceptedCmp1'] == 1)).sum()
casados_segunda = ((ifood['marital_Married'] == 1) & (ifood['AcceptedCmp2'] == 1)).sum()
casados_tercera = ((ifood['marital_Married'] == 1) & (ifood['AcceptedCmp3'] == 1)).sum()
casados_cuarta = ((ifood['marital_Married'] == 1) & (ifood['AcceptedCmp4'] == 1)).sum()
casados_quinta = ((ifood['marital_Married'] == 1) & (ifood['AcceptedCmp5'] == 1)).sum()
casados_ultima = ((ifood['marital_Married'] == 1) & (ifood['Response'] == 1)).sum()
print(f'Personas casadas que aceptaron la primera campaña: \n {casados_primera}')
print(f'Personas casadas que aceptaron la segunda campaña: \n {casados_segunda}')
print(f'Personas casadas que aceptaron la tercera campaña: \n {casados_tercera}')
print(f'Personas casadas que aceptaron la cuarta campaña: \n {casados_cuarta}')
print(f'Personas casadas que aceptaron la quinta campaña: \n {casados_quinta}')
print(f'Personas casadas que aceptaron la última campaña: \n {casados_ultima}')
todos_casados = (casados_primera + casados_segunda + casados_tercera +
                 casados_cuarta + casados_quinta + casados_ultima)
print(f'Total de personas casadas que aceptaron alguna campaña: \n {todos_casados}')
# Out:
# Personas casadas que aceptaron la primera campaña:
#  62
# Personas casadas que aceptaron la segunda campaña:
#  7
# Personas casadas que aceptaron la tercera campaña:
#  63
# Personas casadas que aceptaron la cuarta campaña:
#  62
# Personas casadas que aceptaron la quinta campaña:
#  66
# Personas casadas que aceptaron la última campaña:
#  98
# Total de personas casadas que aceptaron alguna campaña:
#  358

# %%
divorciados_primera = ((ifood['marital_Divorced'] == 1) & (ifood['AcceptedCmp1'] == 1)).sum()
divorciados_segunda = ((ifood['marital_Divorced'] == 1) & (ifood['AcceptedCmp2'] == 1)).sum()
divorciados_tercera = ((ifood['marital_Divorced'] == 1) & (ifood['AcceptedCmp3'] == 1)).sum()
divorciados_cuarta = ((ifood['marital_Divorced'] == 1) & (ifood['AcceptedCmp4'] == 1)).sum()
divorciados_quinta = ((ifood['marital_Divorced'] == 1) & (ifood['AcceptedCmp5'] == 1)).sum()
divorciados_ultima = ((ifood['marital_Divorced'] == 1) & (ifood['Response'] == 1)).sum()
print(f'Personas divorciadas que aceptaron la primera campaña: \n {divorciados_primera}')
print(f'Personas divorciadas que aceptaron la segunda campaña: \n {divorciados_segunda}')
print(f'Personas divorciadas que aceptaron la tercera campaña: \n {divorciados_tercera}')
print(f'Personas divorciadas que aceptaron la cuarta campaña: \n {divorciados_cuarta}')
print(f'Personas divorciadas que aceptaron la quinta campaña: \n {divorciados_quinta}')
print(f'Personas divorciadas que aceptaron la última campaña: \n {divorciados_ultima}')
todos_divorciados = (divorciados_primera + divorciados_segunda + divorciados_tercera +
                     divorciados_cuarta + divorciados_quinta + divorciados_ultima)
print(f'Total de personas divorciadas que aceptaron alguna campaña: \n {todos_divorciados}')
# Out:
# Personas divorciadas que aceptaron la primera campaña:
#  12
# Personas divorciadas que aceptaron la segunda campaña:
#  5
# Personas divorciadas que aceptaron la tercera campaña:
#  20
# Personas divorciadas que aceptaron la cuarta campaña:
#  18
# Personas divorciadas que aceptaron la quinta campaña:
#  13
# Personas divorciadas que aceptaron la última campaña:
#  48
# Total de personas divorciadas que aceptaron alguna campaña:
#  116

# %%
juntados_primera = ((ifood['marital_Together'] == 1) & (ifood['AcceptedCmp1'] == 1)).sum()
juntados_segunda = ((ifood['marital_Together'] == 1) & (ifood['AcceptedCmp2'] == 1)).sum()
juntados_tercera = ((ifood['marital_Together'] == 1) & (ifood['AcceptedCmp3'] == 1)).sum()
juntados_cuarta = ((ifood['marital_Together'] == 1) & (ifood['AcceptedCmp4'] == 1)).sum()
juntados_quinta = ((ifood['marital_Together'] == 1) & (ifood['AcceptedCmp5'] == 1)).sum()
juntados_ultima = ((ifood['marital_Together'] == 1) & (ifood['Response'] == 1)).sum()
print(f'Personas juntadas que aceptaron la primera campaña: \n {juntados_primera}')
print(f'Personas juntadas que aceptaron la segunda campaña: \n {juntados_segunda}')
print(f'Personas juntadas que aceptaron la tercera campaña: \n {juntados_tercera}')
print(f'Personas juntadas que aceptaron la cuarta campaña: \n {juntados_cuarta}')
print(f'Personas juntadas que aceptaron la quinta campaña: \n {juntados_quinta}')
print(f'Personas juntadas que aceptaron la última campaña: \n {juntados_ultima}')
todos_juntados = (juntados_primera + juntados_segunda + juntados_tercera +
                  juntados_cuarta + juntados_quinta + juntados_ultima)
print(f'Total de personas juntadas que aceptaron alguna campaña: \n {todos_juntados}')
# Out:
# Personas juntadas que aceptaron la primera campaña:
#  32
# Personas juntadas que aceptaron la segunda campaña:
#  12
# Personas juntadas que aceptaron la tercera campaña:
#  37
# Personas juntadas que aceptaron la cuarta campaña:
#  42
# Personas juntadas que aceptaron la quinta campaña:
#  43
# Personas juntadas que aceptaron la última campaña:
#  60
# Total de personas juntadas que aceptaron alguna campaña:
#  226

# %%
martial_window_primera = ((ifood['marital_Widow'] == 1) & (ifood['AcceptedCmp1'] == 1)).sum()
martial_window_segunda = ((ifood['marital_Widow'] == 1) & (ifood['AcceptedCmp2'] == 1)).sum()
martial_window_tercera = ((ifood['marital_Widow'] == 1) & (ifood['AcceptedCmp3'] == 1)).sum()
martial_window_cuarta = ((ifood['marital_Widow'] == 1) & (ifood['AcceptedCmp4'] == 1)).sum()
martial_window_quinta = ((ifood['marital_Widow'] == 1) & (ifood['AcceptedCmp5'] == 1)).sum()
martial_window_ultima = ((ifood['marital_Widow'] == 1) & (ifood['Response'] == 1)).sum()
print(f'Personas viudas que aceptaron la primera campaña: \n {martial_window_primera}')
print(f'Personas viudas que aceptaron la segunda campaña: \n {martial_window_segunda}')
print(f'Personas viudas que aceptaron la tercera campaña: \n {martial_window_tercera}')
print(f'Personas viudas que aceptaron la cuarta campaña: \n {martial_window_cuarta}')
print(f'Personas viudas que aceptaron la quinta campaña: \n {martial_window_quinta}')
print(f'Personas viudas que aceptaron la última campaña: \n {martial_window_ultima}')
todos_window = (martial_window_primera + martial_window_segunda + martial_window_tercera +
                martial_window_cuarta + martial_window_quinta + martial_window_ultima)
print(f'Total de personas viudas que aceptaron alguna campaña: \n {todos_window}')
# Out:
# Personas viudas que aceptaron la primera campaña:
#  5
# Personas viudas que aceptaron la segunda campaña:
#  1
# Personas viudas que aceptaron la tercera campaña:
#  4
# Personas viudas que aceptaron la cuarta campaña:
#  10
# Personas viudas que aceptaron la quinta campaña:
#  7
# Personas viudas que aceptaron la última campaña:
#  18
# Total de personas viudas que aceptaron alguna campaña:
#  45

# %%
#tabla con los resultados de aceptación por estado civil
tabla_estado_civil = pd.DataFrame({
    'Estado Civil': ['Soltero', 'Casado', 'Divorciado', 'Juntado', 'Viudo'],
    'Aceptaron Primera Campaña': [estadocivil_primera, casados_primera, divorciados_primera, juntados_primera, martial_window_primera],
    'Aceptaron Segunda Campaña': [estadocivil_segunda, casados_segunda, divorciados_segunda, juntados_segunda, martial_window_segunda],
    'Aceptaron Tercera Campaña': [estadocivil_tercera, casados_tercera, divorciados_tercera, juntados_tercera, martial_window_tercera],
    'Aceptaron Cuarta Campaña': [estadocivil_cuarta, casados_cuarta, divorciados_cuarta, juntados_cuarta, martial_window_cuarta],
    'Aceptaron Quinta Campaña': [estadocivil_quinta, casados_quinta, divorciados_quinta, juntados_quinta, martial_window_quinta],
    'Aceptaron Última Campaña': [estadocivil_ultima, casados_ultima, divorciados_ultima, juntados_ultima, martial_window_ultima]
})
tabla_estado_civil.set_index('Estado Civil', inplace=True)
print("\nTabla de aceptación por estado civil:")
print(tabla_estado_civil)
# Out:
# Tabla de aceptación por estado civil:
#               Aceptaron Primera Campaña  Aceptaron Segunda Campaña  \
# Estado Civil
# Soltero                              31                          5
# Casado                               62                          7
# Divorciado                           12                          5
# Juntado                              32                         12
# Viudo                                 5                          1
#
#               Aceptaron Tercera Campaña  Aceptaron Cuarta Campaña  \
# Estado Civil
# Soltero                              39                        32
# Casado                               63                        62
# Divorciado                           20                        18
# Juntado                              37                        42
# Viudo                                 4                        10
#
#               Aceptaron Quinta Campaña  Aceptaron Última Campaña
# Estado Civil
# ...

# %%
## grafico de barras de personas que aceptaron cada campaña por estado civil, en todas las campañas
plt.figure(figsize=(12, 6))
plt.bar(['Primera', 'Segunda', 'Tercera', 'Cuarta', 'Quinta', 'Última'],
        [estadocivil_primera, estadocivil_segunda, estadocivil_tercera,
         estadocivil_cuarta, estadocivil_quinta, estadocivil_ultima],
        label='Solteros', alpha=0.6)
plt.bar(['Primera', 'Segunda', 'Tercera', 'Cuarta', 'Quinta', 'Última'],
        [casados_primera, casados_segunda, casados_tercera,
         casados_cuarta, casados_quinta, casados_ultima],
        label='Casados', alpha=0.6)
plt.bar(['Primera', 'Segunda', 'Tercera', 'Cuarta', 'Quinta', 'Última'],
        [divorciados_primera, divorciados_segunda, divorciados_tercera,
         divorciados_cuarta, divorciados_quinta, divorciados_ultima],
        label='Divorciados', alpha=0.6)
plt.bar(['Primera', 'Segunda', 'Tercera', 'Cuarta', 'Quinta', 'Última'],
        [juntados_primera, juntados_segunda, juntados_tercera,
         juntados_cuarta, juntados_quinta, juntados_ultima],
        label='Juntados', alpha=0.6)
plt.bar(['Primera', 'Segunda', 'Tercera', 'Cuarta', 'Quinta', 'Última'],
        [martial_window_primera, martial_window_segunda, martial_window_tercera,
         martial_window_cuarta, martial_window_quinta, martial_window_ultima],
        label='Viudos', alpha=0.6)
plt.title('Aceptación de campañas por estado civil')
plt.xlabel('Campañas')
plt.ylabel('Número de personas que aceptaron')
plt.legend()
plt.xticks(rotation=45)
plt.tight_layout()
plt.savefig('aceptacion_campanas_estado_civil.png')
plt.show()

# %% [markdown]
# ## Cuales son los dias minimos despues de la ultima compra?

# %%
minimo_dia_compra = ifood['Recency'].min()
print(f'Día mínimo de compra: \n {minimo_dia_compra}')
maximo_dia_compra = ifood['Recency'].max()
print(f'Día máximo de compra: \n {maximo_dia_compra}')
promedio_dia_compra = ifood['Recency'].mean()
print(f'Día promedio de compra: \n {promedio_dia_compra}')
std_dia_compra = ifood['Recency'].std()
print(f'Desviación estándar de los días de compra: \n {std_dia_compra}')
# Out:
# Día mínimo de compra:
#  0
# Día máximo de compra:
#  99
# Día promedio de compra:
#  49.00907029478458
# Desviación estándar de los días de compra:
#  28.932111370026792

# %%
# histograma de los días de compra
plt.figure(figsize=(10, 6))
plt.hist(ifood['Recency'], bins=30, color='skyblue', edgecolor='black')
plt.title('Distribución de los días de compra')
plt.xlabel('Días desde la última compra')
plt.ylabel('Número de clientes')
plt.tight_layout()
plt.savefig('histograma_dias_compra.png')
plt.show()

# %% [markdown]
# ## Montos totales que gastan por edades

# %%
monto_total_compras = ifood['MntTotal'].sum()
print(f'Monto total de compras: \n {monto_total_compras}')
# Out:
# Monto total de compras:
#  1240896

# %%
monto_total_compras_por_edades = ifood.groupby('Age')['MntTotal'].sum()
# grafico de barras del monto total de compras por edades
plt.figure(figsize=(12, 6))
plt.bar(monto_total_compras_por_edades.index, monto_total_compras_por_edades.values, color='orange')
plt.title('Monto total de compras por edades')
plt.xlabel('Edad')
plt.ylabel('Monto total de compras')
plt.tight_layout()
plt.savefig('monto_total_compras_por_edades.png')
plt.show()

# %%
print(monto_total_compras_por_edades.max())
print(monto_total_compras_por_edades.idxmin())
# Out:
# 48337
# 24

# %% [markdown]
# ## grafica por departamentos

# %%
fish = ifood['MntFishProducts'].sum()
meat = ifood['MntMeatProducts'].sum()
fruits = ifood['MntFruits'].sum()
sweet = ifood['MntSweetProducts'].sum()
gold = ifood['MntGoldProds'].sum()
wine = ifood['MntWines'].sum()

# pie chart de los montos gastados en cada categoría de productos
labels = ['Pescado', 'Carne', 'Frutas', 'Dulces', 'Oro', 'Vino']
sizes = [fish, meat, fruits, sweet, gold, wine]
colors = ['#ff9999','#66b3ff','#99ff99','#ffcc99','#c2c2f0','#ffb3e6']
explode = (0.1, 0, 0, 0, 0, 0)
plt.figure(figsize=(12, 8))
plt.pie(sizes, explode=explode, labels=labels, colors=colors, autopct='%1.1f%%', startangle=140)
plt.title('Distribución del monto gastado por categoría de productos')
plt.tight_layout()
plt.savefig('monto_gastado_por_categoria.png')
plt.show()

# %%
ifood
# Out:
#        Income  Kidhome  Teenhome  Recency  MntWines  MntFruits  \
# 0     58138.0        0         0       58       635         88
# 1     46344.0        1         1       38        11          1
# 2     71613.0        0         0       26       426         49
# 3     26646.0        1         0       26        11          4
# 4     58293.0        1         0       94       173         43
# ...       ...      ...       ...      ...       ...        ...
# 2200  61223.0        0         1       46       709         43
# 2201  64014.0        2         1       56       406          0
# 2202  56981.0        0         0       91       908         48
# 2203  69245.0        0         1        8       428         30
# 2204  52869.0        1         1       40        84          3
#
#       MntMeatProducts  MntFishProducts  MntSweetProducts  MntGoldProds  ...  \
# 0                 546              172                88            88  ...
# ...

# %% [markdown]
# ## El tipo de educacion afecta a la venta?

# %%
## comparacion si la educacion influye en la aceptacion de las campañas
eduacion_2n_Cyle = ifood['education_2n Cycle'].sum()
eduacion_Basic = ifood['education_Basic'].sum()
eduacion_Graduation = ifood['education_Graduation'].sum()
eduacion_Master = ifood['education_Master'].sum()
eduacion_PhD = ifood['education_PhD'].sum()
print(f'Personas con educación de 2n ciclo que aceptaron la primera campaña: \n {eduacion_2n_Cyle}')
print(f'Personas con educación básica que aceptaron la primera campaña: \n {eduacion_Basic}')
print(f'Personas con educación de graduación que aceptaron la primera campaña: \n {eduacion_Graduation}')
print(f'Personas con educación de máster que aceptaron la primera campaña: \n {eduacion_Master}')
print(f'Personas con educación de doctorado que aceptaron la primera campaña: \n {eduacion_PhD}')
# tabla con los resultados de aceptación por educación
tabla_educacion = pd.DataFrame({
    'Educación': ['2n Cycle', 'Basic', 'Graduation', 'Master', 'PhD'],
    'Aceptaron Primera Campaña': [eduacion_2n_Cyle, eduacion_Basic, eduacion_Graduation, eduacion_Master, eduacion_PhD],
    'Aceptaron Segunda Campaña': [ifood['education_2n Cycle'].sum(), ifood['education_Basic'].sum(), ifood['education_Graduation'].sum(), ifood['education_Master'].sum(), ifood['education_PhD'].sum()],
    'Aceptaron Tercera Campaña': [ifood['education_2n Cycle'].sum(), ifood['education_Basic'].sum(), ifood['education_Graduation'].sum(), ifood['education_Master'].sum(), ifood['education_PhD'].sum()],
    'Aceptaron Cuarta Campaña': [ifood['education_2n Cycle'].sum(), ifood['education_Basic'].sum(), ifood['education_Graduation'].sum(), ifood['education_Master'].sum(), ifood['education_PhD'].sum()],
    'Aceptaron Quinta Campaña': [ifood['education_2n Cycle'].sum(), ifood['education_Basic'].sum(), ifood['education_Graduation'].sum(), ifood['education_Master'].sum(), ifood['education_PhD'].sum()],
    'Aceptaron Última Campaña': [ifood['education_2n Cycle'].sum(), ifood['education_Basic'].sum(), ifood['education_Graduation'].sum(), ifood['education_Master'].sum(), ifood['education_PhD'].sum()]
})
tabla_educacion.set_index('Educación', inplace=True)
print("\nTabla de aceptación por educación:")
print(tabla_educacion)
# Out:
# Personas con educación de 2n ciclo que aceptaron la primera campaña:
#  198
# Personas con educación básica que aceptaron la primera campaña:
#  54
# Personas con educación de graduación que aceptaron la primera campaña:
#  1113
# Personas con educación de máster que aceptaron la primera campaña:
#  364
# Personas con educación de doctorado que aceptaron la primera campaña:
#  476
#
# Tabla de aceptación por educación:
#             Aceptaron Primera Campaña  Aceptaron Segunda Campaña  \
# Educación
# 2n Cycle                          198                        198
# Basic                              54                         54
# Graduation                       1113                       1113
# Master                            364                        364
# PhD                               476                        476
#
#             Aceptaron Tercera Campaña  Aceptaron Cuarta Campaña  \
# Educación
# 2n Cycle                          198                       198
# ...

# %%
## gráfico de barras de personas que aceptaron cada campaña por educación, en todas las campañas
plt.figure(figsize=(12, 6))
plt.bar(['Primera', 'Segunda', 'Tercera', 'Cuarta', 'Quinta', 'Última'],
        [
            eduacion_2n_Cyle, ifood['education_2n Cycle'].sum(), ifood['education_2n Cycle'].sum(),
            ifood['education_2n Cycle'].sum(), ifood['education_2n Cycle'].sum(), ifood['education_2n Cycle'].sum()],
        label='2n Cycle', alpha=0.6)
plt.bar(['Primera', 'Segunda', 'Tercera', 'Cuarta', 'Quinta', 'Última'],
        [
            eduacion_Basic, ifood['education_Basic'].sum(), ifood['education_Basic'].sum(),
            ifood['education_Basic'].sum(), ifood['education_Basic'].sum(), ifood['education_Basic'].sum()],
        label='Basic', alpha=0.6)
plt.bar(['Primera', 'Segunda', 'Tercera', 'Cuarta', 'Quinta', 'Última'],
        [
            eduacion_Graduation, ifood['education_Graduation'].sum(), ifood['education_Graduation'].sum(),
            ifood['education_Graduation'].sum(), ifood['education_Graduation'].sum(), ifood['education_Graduation'].sum()],
        label='Graduation', alpha=0.6)
plt.bar(['Primera', 'Segunda', 'Tercera', 'Cuarta', 'Quinta', 'Última'],
        [
            eduacion_Master, ifood['education_Master'].sum(), ifood['education_Master'].sum(),
            ifood['education_Master'].sum(), ifood['education_Master'].sum(), ifood['education_Master'].sum()],
        label='Master', alpha=0.6)
plt.bar(['Primera', 'Segunda', 'Tercera', 'Cuarta', 'Quinta', 'Última'],
        [
            eduacion_PhD, ifood['education_PhD'].sum(), ifood['education_PhD'].sum(),
            ifood['education_PhD'].sum(), ifood['education_PhD'].sum(), ifood['education_PhD'].sum()],
        label='PhD', alpha=0.6)
plt.title('Aceptación de campañas por educación')
plt.xlabel('Campañas')
plt.ylabel('Número de personas que aceptaron')
plt.legend()
plt.xticks(rotation=45)
plt.tight_layout()
plt.savefig('aceptacion_campanas_educacion.png')
plt.show()

# %% [markdown]
# ## Numero de compras con visitas al sitio web

# %%
plt.figure(figsize=(12, 6))
plt.bar(ifood['NumDealsPurchases'].value_counts().index, ifood['NumDealsPurchases'].value_counts().values, label='Compras con descuento', alpha=0.6)
plt.bar(ifood['NumCatalogPurchases'].value_counts().index, ifood['NumCatalogPurchases'].value_counts().values, label='Compras por catálogo', alpha=0.6)
plt.bar(ifood['NumStorePurchases'].value_counts().index, ifood['NumStorePurchases'].value_counts().values, label='Compras en tienda', alpha=0.6)
plt.bar(ifood['NumWebPurchases'].value_counts().index, ifood['NumWebPurchases'].value_counts().values, label='Compras en web', alpha=0.6)
plt.bar(ifood['NumWebVisitsMonth'].value_counts().index, ifood['NumWebVisitsMonth'].value_counts().values, label='Visitas al sitio web', alpha=0.6)
plt.title('Número de compras y visitas al sitio web')
plt.xlabel('Número de compras/visitas')
plt.ylabel('Número de clientes')
plt.legend()
plt.xticks(rotation=45)
plt.tight_layout()
plt.savefig('compras_visitas_web.png')
plt.show()
